# %%
from __future__ import absolute_import, division, print_function, unicode_literals

import os

import tensorflow as tf
from tensorflow import keras

# %%
ls saved_models
# Out:
# 1579015228/

# %%
entity_model = tf.keras.models.load_model('saved_models/1579015228') # load entity models

# %%
import imageio
# %matplotlib inline
import IPython.display as display
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

f = "sCy7BKRjthZr13Y.png"
im = imageio.imread(f)
if im.shape[0]>im.shape[1]:
    im = im[:im.shape[1],:im.shape[1],:]
plt.imshow(im)
plt.show()

# %%
import cv2
if len(im.shape) > 2 and im.shape[2] == 4:
    #convert the image from RGBA2RGB
    im = cv2.cvtColor(im, cv2.COLOR_BGRA2BGR)
res = cv2.resize(im, dsize=(224, 224), interpolation=cv2.INTER_CUBIC)
plt.imshow(res)
plt.show()
res.shape
# Out:
# (224, 224, 3)

# %%
res = np.expand_dims(res, axis=0)
    
entity_model.predict(res)
# Out:
# array([[0.2919191 , 0.70808095]], dtype=float32)
