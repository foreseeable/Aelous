# %%
from __future__ import absolute_import, division, print_function, unicode_literals
# %matplotlib inline
import pickle
import cv2
from matplotlib import pyplot as plt
from shutil import copyfile
import tensorflow as tf
import IPython.display as display
import tensorflow_hub as hub
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import os
import pathlib
import glob
import imageio

AUTOTUNE = tf.data.experimental.AUTOTUNE


# load train data and test data
with open('data.pickle','rb') as f:
    train,test = pickle.load(f)

# %%
# copy images to corresponding directories
for x in train:
    copyfile('/home/wcmg_chen/ml-camp/webpage-classification/'+x['render'],'./data/'+x['is entity']+'/'+x['render'].split('render')[-1])
for x in test:
    copyfile('/home/wcmg_chen/ml-camp/webpage-classification/'+x['render'],'./test/'+x['is entity']+'/'+x['render'].split('render')[-1])

# %%
BATCH_SIZE = 32
IMG_HEIGHT = 224
IMG_WIDTH = 224
image_count = len(train)
STEPS_PER_EPOCH = np.ceil(image_count/BATCH_SIZE)
CLASS_NAMES = np.array(["0","1"])

# crop screeshot that are too long
def cropData(path):
    for f in glob.glob('./'+path+'/*/*.png'):
        im = imageio.imread(f)
        if im.shape[0]>im.shape[1]:
            im = im[:im.shape[1],:im.shape[1],:]
        imageio.imwrite(f,im)

cropData('data')

# %%
cropData('test')

# %%
feature_extractor_url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/2" #@param {type:"string"}
from tensorflow.keras import layers

feature_extractor_layer = hub.KerasLayer(feature_extractor_url,
                                         input_shape=(IMG_HEIGHT,IMG_WIDTH,3))
feature_extractor_layer.trainable = False

model = tf.keras.Sequential([
  feature_extractor_layer,
  layers.Dense(2, activation='softmax')
])

# %%
#load train data
list_ds = tf.data.Dataset.list_files(str('./data/*/*.png'))
for f in list_ds.take(5):
  print(f.numpy())
# Out:
# b'./data/0/766.png'
# b'./data/0/1331.png'
# b'./data/0/718.png'
# b'./data/0/2382.png'
# b'./data/0/784.png'

# %%
def get_label(file_path):
  # convert the path to a list of path components
  parts = tf.strings.split(file_path, os.path.sep)
  # The second to last is the class-directory
  return parts[-2] == CLASS_NAMES

# %%
def decode_img(img):
  # convert the compressed string to a 3D uint8 tensor
  img = tf.image.decode_jpeg(img, channels=3)
  
  # Use `convert_image_dtype` to convert to floats in the [0,1] range.
  img = tf.image.convert_image_dtype(img, tf.float32)
    
  # crop too long webpage
  #if img.shape[0]>img.shape[1]:
  #  img = tf.image.crop_to_bounding_box(img,0,0,img.shape[1],img.shape[1])
  # resize the image to the desired size.
  return tf.image.resize(img,[IMG_HEIGHT,IMG_WIDTH])

def process_path(file_path):
  label = get_label(file_path)
  #print(label)
  # load the raw data from the file as a string
  img = tf.io.read_file(file_path)
  img = decode_img(img)
  return img, label

# %%
# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
labeled_ds = list_ds.map(process_path)

# %%
for image, label in labeled_ds.take(3):
  print("Image shape: ", image.numpy().shape)
  print("Label: ", label.numpy())
  image_ = np.squeeze(image) # you can give axis attribute if you wanna squeeze in specific dimension
  plt.imshow(image_)
  plt.show()
# Out:
# Image shape:  (224, 224, 3)
# Label:  [ True False]
# Image shape:  (224, 224, 3)
# Label:  [False  True]
# Image shape:  (224, 224, 3)
# Label:  [ True False]

# %%
def prepare_for_training(ds, cache=True, shuffle_buffer_size=1000):
  # This is a small dataset, only load it once, and keep it in memory.
  # use `.cache(filename)` to cache preprocessing work for datasets that don't
  # fit in memory.
  if cache:
    if isinstance(cache, str):
      ds = ds.cache(cache)
    else:
      ds = ds.cache()
  ds = ds.shuffle(buffer_size=shuffle_buffer_size)

  # Repeat forever
  ds = ds.repeat()

  ds = ds.batch(BATCH_SIZE)

  # `prefetch` lets the dataset fetch batches in the background while the model
  # is training.
  ds = ds.prefetch(buffer_size=AUTOTUNE)

  return ds

train_ds = prepare_for_training(labeled_ds)

# %%
model.compile(
  optimizer=tf.keras.optimizers.Adam(),
  loss='categorical_crossentropy',
  metrics=['acc'])

# %%
history = model.fit_generator(train_ds, epochs=100,
                              steps_per_epoch=STEPS_PER_EPOCH,
                              callbacks = [])
# Out:
# Train for 73.0 steps
# Epoch 1/100
# 73/73 [==============================] - 53s 728ms/step - loss: 0.5073 - acc: 0.7710
# Epoch 2/100
# 73/73 [==============================] - 14s 191ms/step - loss: 0.4337 - acc: 0.7967
# Epoch 3/100
# 73/73 [==============================] - 14s 189ms/step - loss: 0.3953 - acc: 0.8211
# Epoch 4/100
# 73/73 [==============================] - 14s 192ms/step - loss: 0.3734 - acc: 0.8386
# Epoch 5/100
# 73/73 [==============================] - 14s 188ms/step - loss: 0.3453 - acc: 0.8532
# Epoch 6/100
# 73/73 [==============================] - 14s 190ms/step - loss: 0.3368 - acc: 0.8592
# Epoch 7/100
# 73/73 [==============================] - 14s 192ms/step - loss: 0.3232 - acc: 0.8622
# Epoch 8/100
# 73/73 [==============================] - 14s 190ms/step - loss: 0.3079 - acc: 0.8682
# Epoch 9/100
# 73/73 [==============================] - 14s 191ms/step - loss: 0.3050 - acc: 0.8771
# Epoch 10/100
# ...

# %%
test_ds = tf.data.Dataset.list_files(str('./test/*/*.png'))
for f in test_ds.take(5):
  print(f.numpy())
#test_img = test_ds.map(lambda x:decode_img(tf.io.read_file(x)))
test_data = test_ds.map(process_path, num_parallel_calls=AUTOTUNE)
test_np = np.array(list(test_data.as_numpy_iterator()))
testX = test_np[:,0]
testY = test_np[:,1]
testX = np.zeros(test_np[:,0].shape+test_np[0,0].shape)
testY = np.zeros(test_np[:,1].shape+test_np[0,1].shape)
for i in range(len(test_np[:,0])):
    testX[i,:] = test_np[i,0]
    testY[i,:] = test_np[i,1]

model.evaluate(testX,testY)
# Out:
# b'./test/0/1450.png'
# b'./test/0/1770.png'
# b'./test/1/1150.png'
# b'./test/0/1808.png'
# b'./test/0/1393.png'
# 259/259 [==============================] - 2s 6ms/sample - loss: 0.4597 - acc: 0.8417
# [0.45974957792656534, 0.8416988]
